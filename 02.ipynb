# %%
from PIL import Image
from image_tool import*
from IPython.display import display

# %%
my_dir = r'C:\Users\ADMIN\jupyter_Project\Computer_Vision\img\01'

# %%
img01 = get_image_list(my_dir)

# %%
for img in img01:
    print(img.size, img.format)
    display(img)
# Out:
# (120, 147) JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=120x147>
# (225, 225) PNG
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225>
# (147, 176) JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=147x176>
# (120, 147) JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=120x147>
# (120, 147) PNG
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=120x147>
# (225, 225) PNG
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225>

# %%
print("Định dạng ảnh: ", img01.format)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("Định dạng ảnh: ", img01.format)
#
# AttributeError: 'list' object has no attribute 'format'

# %%
print("Kích thước ảnh: ", img01.size)

# %%
# img01.close()

# %%
new_img_01_path = dir + '/new_01.jpeg'
new_img_png_01_path = dir + '/new_01.png'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)
